# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pylab as plt
plt.style.use('ggplot')

# %%
df_demo = sns.load_dataset('iris')

# %%
df_demo
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Correlation

# %%
# vars to analize
vars = ['sepal_length','sepal_width','petal_length','petal_width']

# %%
# calculate correlation
corr = df_demo[vars].corr()

# %%
# visualize correlation

fig, axs = plt.subplots(1, figsize=(10, 10), dpi=150, sharey=False)

sns.heatmap(
    corr,
    cmap= sns.color_palette("vlag", as_cmap=True),
    annot= True, # show each corr value
    ax= axs 
    )

axs.set_title('Correlation')
plt.show()

# %% [markdown]
# # Pair plot: shows dist of all possible pair of features

# %% [markdown]
# ## Plotting every data point

# %%
sns.pairplot(df_demo, hue='species')
plt.show()
# Out:
# /Users/joelcr23/miniconda3/envs/mlai/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Plotting prob density function

# %%
sns.pairplot(df_demo, kind='kde', hue='species')
plt.show()
# Out:
# /Users/joelcr23/miniconda3/envs/mlai/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
